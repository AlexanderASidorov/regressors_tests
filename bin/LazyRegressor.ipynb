# %%
# Импортируем нужные библиотеки
import numpy as np
import matplotlib.pyplot as plt

from lazypredict.Supervised import LazyRegressor # класс для поиска наилучшей модели для данного набора данных
from sklearn.model_selection import train_test_split # класс разбиения на данные для обучения и для проверки

# импортируем функции
from functions import generate_random_array, plot_true_vs_predicted

# %%
# Основная функция
def main_function (x, y, z):
    function = np.sin(x)*np.cos(2*x) + np.sin(y)*np.cos(2*y) + np.sin(z)*np.cos(2*z)
    return function# генерим случайный массив признаков от -10 до +10

# %%
# генерим случайный массив признаков от -10 до +10
xyz = generate_random_array(1000, 3, -10, +10)
xyz[:10, :]
# Out:
# array([[ 5.47912097, -1.2224312 ,  7.1719584 ],
#        [ 3.94736058, -8.11645304,  9.51244703],
#        [ 5.22279404,  5.72128611, -7.43772735],
#        [-0.99228124, -2.58403952,  8.53529978],
#        [ 2.8773024 ,  6.45523227, -1.13171602],
#        [-5.45522556,  1.09169574, -8.72365488],
#        [ 6.55262344,  2.63328798,  5.1617548 ],
#        [-2.90948064,  9.41396049,  7.86242243],
#        [ 5.56766994, -6.10722584, -0.66557993],
#        [-9.12392468, -6.91421016,  3.66097906]])

# %%
# Подставляем сгенерированный массив в функцию
results = main_function(*xyz.T)
results[:10]
# Out:
# array([ 0.58839688,  0.77888121,  0.84130589, -0.05673882,  0.96473248,
#        -0.68108981,  1.04538504, -1.19469597, -0.07363149, -0.67534831])

# %%
# разбиваем данные для данные для обучения и для проверки
X_train, X_test, y_train, y_test = train_test_split(xyz,results,test_size=0.1,random_state=42)

# %%
# попробуем найти модель подходящую для нашего набора данных
# Создаём и запускаем LazyRegressor
reg = LazyRegressor(
    verbose=0,            # 0 — тихо, 1 — показывает прогресс
    ignore_warnings=True, # игнорировать предупреждения (например, от моделей, которые не сходятся)
    custom_metric=None    # можно добавить свою метрику, но по умолчанию — R² 
)

# Обучение и предсказание
models, predictions = reg.fit(X_train, X_test, y_train, y_test)

# Вывод результатов
print(models)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000911 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 765
# [LightGBM] [Info] Number of data points in the train set: 900, number of used features: 3
# [LightGBM] [Info] Start training from score 0.016603
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# LGBMRegressor                                0.92       0.92  0.24        0.23
# HistGradientBoostingRegressor                0.91       0.91  0.27        0.18
# XGBRegressor                                 0.85       0.85  0.33        0.36
# GradientBoostingRegressor                    0.76       0.76  0.43        0.13
# RandomForestRegressor                        0.55       0.56  0.58        0.26
# ExtraTreesRegressor                          0.51       0.53  0.60        0.14
# BaggingRegressor                             0.49       0.51  0.62        0.04
# AdaBoostRegressor                            0.32       0.34  0.71        0.10
# DecisionTreeRegressor                        0.13       0.15  0.81        0.01
# KNeighborsRegressor                          0.04       0.07  0.85        0.01
# RANSACRegressor                              0.04       0.07  0.85        0.07
# LinearSVR                                    0.02       0.05  0.86        0.01
# SGDRegressor                                 0.02       0.05  0.86        0.01
# HuberRegressor                               0.02       0.05  0.86        0.01
# LassoLarsCV                                  0.02       0.05  0.86        0.01
# TransformedTargetRegressor                   0.02       0.05  0.86        0.01
# LarsCV                                       0.02       0.05  0.86        0.01
# LinearRegression                             0.02       0.05  0.86        0.01
# Lars                                         0.02       0.05  0.86        0.01
# Ridge                                        0.02       0.05  0.86        0.01
# LassoCV                                      0.02       0.05  0.86        0.04
# ElasticNetCV                                 0.02       0.05  0.86        0.04
# RidgeCV                                      0.02       0.05  0.86        0.01
# KernelRidge                                  0.02       0.05  0.86        0.02
# OrthogonalMatchingPursuitCV                  0.01       0.04  0.86        0.01
# OrthogonalMatchingPursuit                    0.01       0.04  0.86        0.01
# LassoLarsIC                                  0.01       0.04  0.86        0.01
# BayesianRidge                                0.01       0.04  0.86        0.04
# TweedieRegressor                            -0.00       0.03  0.87        0.01
# NuSVR                                       -0.03       0.01  0.88        0.04
# MLPRegressor                                -0.03       0.00  0.88        0.39
# DummyRegressor                              -0.03      -0.00  0.88        0.01
# LassoLars                                   -0.03      -0.00  0.88        0.01
# ElasticNet                                  -0.03      -0.00  0.88        0.01
# Lasso                                       -0.03      -0.00  0.88        0.01
# QuantileRegressor                           -0.04      -0.00  0.88        0.05
# SVR                                         -0.08      -0.05  0.90        0.07
# ExtraTreeRegressor                          -0.46      -0.41  1.04        0.01
# PassiveAggressiveRegressor                  -2.63      -2.52  1.65        0.01
# GaussianProcessRegressor                  -100.68     -97.60  8.72        0.04
