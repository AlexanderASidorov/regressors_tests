# %%
# Импортируем нужные библиотеки
import numpy as np
import matplotlib.pyplot as plt

from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split # класс разбиения на данные для обучения и для проверки
from sklearn.preprocessing import MinMaxScaler
# импортируем функции
from functions import *

# %%
# Исходные данные
# создаем объект класса Functions 
main_function = Functions()

# определяем базовое число для случайной выборки
main_function.random_seed = 99

# определяем количетсво строк для обучения
main_function.n_samples = 1000

# пределы варьирования признаков
main_function.limits = (-10, 10)

# определяем вид функции
main_function.set_function(main_function.trigonometric)

# создаем объект для генерации данных в кодированном масштабе
training_matrix = Generate_coded_data(main_function, main_function.n_samples, random_seed=main_function.random_seed)

# назначаем тип матрицы в кодированном масштабе
training_matrix.set_matrix_type('lhs') # в данном случае латинский гиперкуб
#training_matrix.X_coded


# Переводим кодированный масштаб в натуральный и расчитываем выходную функцию
# класс для генерации данных в натуральном масштабе
training_data = Generate_natural_data(main_function, training_matrix.X_coded)
# пересчитываем кодированный в натуральный масштаб
training_data.convert_coded_to_natural()

# %%
# Создаём модель
model01 = XGBRegressor(
                    n_estimators=1000,
                    max_depth=3,
                    learning_rate=0.1,
                    reg_alpha=0.5,
                    reg_lambda=0.5,
                    subsample=0.8,
                    random_state=1488,
                    verbosity=0
                    )
model01.fit(training_data.features, training_data.target);

# %%
# генерим еще случайные данные, в этот раз для проверки модели (описание действий см. выше)
testing_matrix = Generate_coded_data(main_function, int(main_function.n_samples*0.1), random_seed=42)
testing_matrix.set_matrix_type('lhs')
testing_data = Generate_natural_data(main_function, testing_matrix.X_coded)
testing_data.convert_coded_to_natural()

# %%
# Расчитываем отклик по данным для проверки
y_pred_test = model01.predict(testing_data.features)
# посмотрим на результат
plot_true_vs_predicted (testing_data.target, y_pred_test, title= f'XGBRegressor test. Function is {main_function.main_function_name}. ')
